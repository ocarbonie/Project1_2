# %%
#import libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#importing the file

filename= "datasets/DC_Properties.csv"
df = pd.read_csv(filename)
df
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# 12              12       2          0  Hot Water Rad  N        2.0      9
# 13              13       2          0      Warm Cool  Y        2.0     11
# 14              14       3          1      Warm Cool  Y        2.0      5
# 15              15       2          1      Warm Cool  Y        2.0      9
# 16              16       3          1      Warm Cool  Y        1.0      8
# 17              17       2          0  Hot Water Rad  N        1.0      6
# 18              18       3          1  Hot Water Rad  Y        2.0     10
# 19              19       3          1  Hot Water Rad  Y        2.0      9
# 20              20       3          1  Hot Water Rad  Y        1.0     14
# 21              21       3          0     Forced Air  Y        2.0     12
# 22              22       1          0     Forced Air  Y        1.0      6
# 23              23       2          1     Forced Air  Y        1.0      5
# 24              24       2          1  Hot Water Rad  Y        1.0      8
# 25              25       1          0  Hot Water Rad  N        1.0      8
# 26              26       1          0  Hot Water Rad  N        1.0     10
# 27              27       3          0  Hot Water Rad  Y        4.0      9
# 28              28       3          0      Warm Cool  Y        2.0     10
# 29              29       3          1     Forced Air  Y        2.0     11
# ...            ...     ...        ...            ... ..        ...    ...
# 158927      158927       2          0        Ht Pump  Y        NaN      6
# 158928      158928       2          1        Ht Pump  Y        NaN      5
# 158929      158929       2          1        Ht Pump  Y        NaN      5
# 158930      158930       2          0     Forced Air  N        NaN      4
# 158931      158931       2          1     Forced Air  N        NaN      4
# 158932      158932       2          1     Forced Air  N        NaN      4
# 158933      158933       2          0        Ht Pump  Y        NaN      4
# 158934      158934       1          1        Ht Pump  Y        NaN      3
# 158935      158935       1          0        Ht Pump  Y        NaN      3
# 158936      158936       1          0        Ht Pump  Y        NaN      3
# 158937      158937       1          0     Forced Air  Y        NaN      4
# 158938      158938       2          0      Warm Cool  Y        NaN      7
# 158939      158939       1          0     Forced Air  Y        NaN      4
# 158940      158940       2          0     Forced Air  Y        NaN      7
# 158941      158941       1          0     Forced Air  Y        NaN      4
# 158942      158942       2          0     Forced Air  Y        NaN      7
# 158943      158943       2          1     Forced Air  Y        NaN      5
# 158944      158944       2          1     Forced Air  Y        NaN      5
# 158945      158945       1          0     Forced Air  Y        NaN      3
# 158946      158946       1          0     Forced Air  Y        NaN      4
# 158947      158947       2          0     Forced Air  Y        NaN      4
# 158948      158948       2          0     Forced Air  Y        NaN      4
# 158949      158949       1          1     Forced Air  Y        NaN      4
# 158950      158950       3          0     Forced Air  Y        NaN      5
# 158951      158951       3          1     Forced Air  Y        NaN      5
# 158952      158952       1          0     Forced Air  Y        NaN      3
# 158953      158953       1          0     Forced Air  Y        NaN      4
# 158954      158954       2          0     Forced Air  Y        NaN      4
# 158955      158955       1          0      Warm Cool  Y        NaN      2
# 158956      158956       1          0      Warm Cool  Y        NaN      2
#
#         BEDRM     AYB  YR_RMDL   ...     LONGITUDE       ASSESSMENT_NBHD  \
# 0           4  1910.0   1988.0   ...    -77.040832            Old City 2
# 1           5  1898.0   2007.0   ...    -77.040764            Old City 2
# 2           5  1910.0   2009.0   ...    -77.040678            Old City 2
# 3           5  1900.0   2003.0   ...    -77.040629            Old City 2
# 4           3  1913.0   2012.0   ...    -77.039361            Old City 2
# 5           5  1913.0      NaN   ...    -77.039715            Old City 2
# 6           2  1917.0   1988.0   ...    -77.041055            Old City 2
# 7           4  1906.0   2011.0   ...    -77.040129            Old City 2
# 8           3  1908.0   2008.0   ...    -77.039903            Old City 2
# 9           2  1908.0   1979.0   ...    -77.040081            Old City 2
# 10          5  1890.0   1950.0   ...    -77.040760            Old City 2
# 11          6  1905.0      NaN   ...    -77.039718            Old City 2
# 12          5  1894.0   1979.0   ...    -77.039569            Old City 2
# 13          5  1885.0   1979.0   ...    -77.039644            Old City 2
# 14          3  1917.0   2000.0   ...    -77.039716            Old City 2
# 15          4  1908.0   1990.0   ...    -77.039784            Old City 2
# 16          3  1908.0   2006.0   ...    -77.039844            Old City 2
# 17          3  1908.0   1987.0   ...    -77.039961            Old City 2
# 18          4  1908.0   2006.0   ...    -77.040020            Old City 2
# 19          3  1908.0   2013.0   ...    -77.040138            Old City 2
# 20          5  1880.0   2009.0   ...    -77.033774            Old City 2
# 21          3  1880.0   2009.0   ...    -77.033838            Old City 2
# 22          3  1880.0   2010.0   ...    -77.033925            Old City 2
# 23          3  1880.0   2010.0   ...    -77.033972            Old City 2
# 24          3  1880.0   2004.0   ...    -77.034070            Old City 2
# 25          4  1880.0   2010.0   ...    -77.034156            Old City 2
# 26          5  1900.0   2004.0   ...    -77.034258            Old City 2
# 27          3  1900.0   1963.0   ...    -77.034182            Old City 2
# 28          4  1900.0   1960.0   ...    -77.034119            Old City 2
# 29          3  1900.0   2014.0   ...    -77.034051            Old City 2
# ...       ...     ...      ...   ...           ...                   ...
# 158927      3  1993.0   1993.0   ...    -77.019274            Old City 2
# 158928      2  2013.0      NaN   ...    -77.019274            Old City 2
# 158929      2  2013.0      NaN   ...    -77.019274            Old City 2
# 158930      2  1900.0   2003.0   ...    -77.019243            Old City 2
# 158931      2  1900.0   2003.0   ...    -77.019243            Old City 2
# 158932      2  1900.0   2003.0   ...    -77.019243            Old City 2
# 158933      2  1880.0   2016.0   ...    -77.019243            Old City 2
# 158934      1  1880.0   2016.0   ...    -77.019243            Old City 2
# 158935      1  1880.0   2016.0   ...    -77.019243            Old City 2
# 158936      1  1880.0   2016.0   ...    -77.019243            Old City 2
# 158937      2  1992.0   1992.0   ...    -77.019420            Old City 2
# 158938      4  1992.0   1992.0   ...    -77.019420            Old City 2
# 158939      2  1992.0   1992.0   ...    -77.019420            Old City 2
# 158940      4  1992.0   1992.0   ...    -77.019420            Old City 2
# 158941      2  1992.0   1992.0   ...    -77.019420            Old City 2
# 158942      4  1992.0   1992.0   ...    -77.019420            Old City 2
# 158943      2  2004.0   2004.0   ...    -77.019420            Old City 2
# 158944      2  2004.0   2004.0   ...    -77.019420            Old City 2
# 158945      1  1938.0   2006.0   ...    -77.019420            Old City 2
# 158946      2  1938.0   2006.0   ...    -77.019420            Old City 2
# 158947      2  1938.0   2006.0   ...    -77.019420            Old City 2
# 158948      2  1938.0   2006.0   ...    -77.019420            Old City 2
# 158949      1  1938.0   2006.0   ...    -77.019420            Old City 2
# 158950      3  1938.0   2006.0   ...    -77.019420            Old City 2
# 158951      3  1938.0   2006.0   ...    -77.019420            Old City 2
# 158952      1  1938.0   2006.0   ...    -77.019420            Old City 2
# 158953      2  1938.0   2006.0   ...    -77.019420            Old City 2
# 158954      2  1920.0   2007.0   ...    -77.019420            Old City 2
# 158955      0  1965.0      NaN   ...    -77.018230  Southwest Waterfront
# 158956      0  1965.0      NaN   ...    -77.018230  Southwest Waterfront
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# 0        040 D Old City 2        4201.0  004201 2006  Ward 2     152
# 1        040 D Old City 2        4201.0  004201 2006  Ward 2     152
# 2        040 D Old City 2        4201.0  004201 2006  Ward 2     152
# 3        040 D Old City 2        4201.0  004201 2006  Ward 2     152
# 4        040 D Old City 2        4201.0  004201 2006  Ward 2     152
# 5        040 D Old City 2        4201.0  004201 2006  Ward 2     152
# 6        040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 7        040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 8        040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 9        040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 10       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 11       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 12       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 13       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 14       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 15       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 16       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 17       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 18       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 19       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 20       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 21       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 22       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 23       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 24       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 25       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 26       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 27       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 28       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 29       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# ...                   ...           ...          ...     ...     ...
# 158927   040 G Old City 2        4801.0          NaN  Ward 6     475
# 158928   040 G Old City 2        4801.0          NaN  Ward 6     475
# 158929   040 G Old City 2        4801.0          NaN  Ward 6     475
# 158930   040 B Old City 2        4801.0          NaN  Ward 6     476
# 158931   040 B Old City 2        4801.0          NaN  Ward 6     476
# 158932   040 B Old City 2        4801.0          NaN  Ward 6     476
# 158933   040 B Old City 2        4801.0          NaN  Ward 6     476
# 158934   040 B Old City 2        4801.0          NaN  Ward 6     476
# 158935   040 B Old City 2        4801.0          NaN  Ward 6     476
# 158936   040 B Old City 2        4801.0          NaN  Ward 6     476
# 158937   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158938   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158939   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158940   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158941   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158942   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158943   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158944   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158945   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158946   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158947   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158948   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158949   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158950   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158951   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158952   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158953   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158954   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158955                NaN       11000.0          NaN  Ward 6     504
# 158956                NaN       11000.0          NaN  Ward 6     504
#
#                 X          Y QUADRANT
# 0      -77.040429  38.914881       NW
# 1      -77.040429  38.914881       NW
# 2      -77.040429  38.914881       NW
# 3      -77.040429  38.914881       NW
# 4      -77.040429  38.914881       NW
# 5      -77.040429  38.914881       NW
# 6      -77.040429  38.914881       NW
# 7      -77.040429  38.914881       NW
# 8      -77.040429  38.914881       NW
# 9      -77.040429  38.914881       NW
# 10     -77.040429  38.914881       NW
# 11     -77.040429  38.914881       NW
# 12     -77.040429  38.914881       NW
# 13     -77.040429  38.914881       NW
# 14     -77.040429  38.914881       NW
# 15     -77.040429  38.914881       NW
# 16     -77.040429  38.914881       NW
# 17     -77.040429  38.914881       NW
# 18     -77.040429  38.914881       NW
# 19     -77.040429  38.914881       NW
# 20     -77.033366  38.911716       NW
# 21     -77.033366  38.911716       NW
# 22     -77.033366  38.911716       NW
# 23     -77.033366  38.911716       NW
# 24     -77.033366  38.911716       NW
# 25     -77.033366  38.911716       NW
# 26     -77.033366  38.911716       NW
# 27     -77.033366  38.911716       NW
# 28     -77.033366  38.911716       NW
# 29     -77.033366  38.911716       NW
# ...           ...        ...      ...
# 158927 -77.019277  38.914287       NW
# 158928 -77.019277  38.914287       NW
# 158929 -77.019277  38.914287       NW
# 158930 -77.019245  38.912954       NW
# 158931 -77.019245  38.912954       NW
# 158932 -77.019245  38.912954       NW
# 158933 -77.019245  38.912954       NW
# 158934 -77.019245  38.912954       NW
# 158935 -77.019245  38.912954       NW
# 158936 -77.019245  38.912954       NW
# 158937 -77.019422  38.911848       NW
# 158938 -77.019422  38.911848       NW
# 158939 -77.019422  38.911848       NW
# 158940 -77.019422  38.911848       NW
# 158941 -77.019422  38.911848       NW
# 158942 -77.019422  38.911848       NW
# 158943 -77.019422  38.911848       NW
# 158944 -77.019422  38.911848       NW
# 158945 -77.019422  38.911848       NW
# 158946 -77.019422  38.911848       NW
# 158947 -77.019422  38.911848       NW
# 158948 -77.019422  38.911848       NW
# 158949 -77.019422  38.911848       NW
# 158950 -77.019422  38.911848       NW
# 158951 -77.019422  38.911848       NW
# 158952 -77.019422  38.911848       NW
# 158953 -77.019422  38.911848       NW
# 158954 -77.019422  38.911848       NW
# 158955 -77.018232  38.872961       SW
# 158956 -77.018232  38.872961       SW
#
# [158957 rows x 49 columns]

# %%
#Looking for duplicates
dupe = df.duplicated()

# %%
df.loc[dupe]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
#These are all the columns
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# CMPLX_NUM             float64
# LIVING_GBA            float64
# FULLADDRESS            object
# CITY                   object
# STATE                  object
# ZIPCODE               float64
# NATIONALGRID           object
# LATITUDE              float64
# LONGITUDE             float64
# ASSESSMENT_NBHD        object
# ASSESSMENT_SUBNBHD     object
# CENSUS_TRACT          float64
# CENSUS_BLOCK           object
# WARD                   object
# SQUARE                 object
# X                     float64
# Y                     float64
# QUADRANT               object
# dtype: object

# %% [markdown]
# # Creating a Smaller dataSet with less columns

# %%
#create a new dataFrame with bedrooms, bathrooms, price, year, year remodeled, city, state, zipcode, heat, ac, stories, style
df_new = df[['ZIPCODE', 'STORIES', 'AYB', 'YR_RMDL', 'CNDTN','BEDRM', 'BATHRM', 'HEAT', 'AC' , 'PRICE']]

# %%
df_new.head(100)
# Out:
#     ZIPCODE  STORIES     AYB  YR_RMDL      CNDTN  BEDRM  BATHRM  \
# 0   20009.0      3.0  1910.0   1988.0       Good      4       4
# 1   20009.0      3.0  1898.0   2007.0       Good      5       3
# 2   20009.0      3.0  1910.0   2009.0  Very Good      5       3
# 3   20009.0      3.0  1900.0   2003.0       Good      5       3
# 4   20009.0      3.0  1913.0   2012.0       Good      3       2
# 5   20009.0      4.0  1913.0      NaN       Good      5       3
# 6   20009.0      2.0  1917.0   1988.0    Average      2       1
# 7   20009.0      3.0  1906.0   2011.0    Average      4       3
# 8   20009.0      2.0  1908.0   2008.0  Very Good      3       3
# 9   20009.0      2.0  1908.0   1979.0    Average      2       1
# 10  20009.0      3.0  1890.0   1950.0       Fair      5       3
# 11  20009.0      3.0  1905.0      NaN    Average      6       5
# 12  20009.0      3.0  1894.0   1979.0    Average      5       2
# 13  20009.0      3.0  1885.0   1979.0    Average      5       2
# 14  20009.0      2.0  1917.0   2000.0  Very Good      3       3
# 15  20009.0      2.0  1908.0   1990.0    Average      4       2
# 16  20009.0      2.0  1908.0   2006.0  Very Good      3       3
# 17  20009.0      2.0  1908.0   1987.0    Average      3       2
# 18  20009.0      2.0  1908.0   2006.0       Good      4       3
# 19  20009.0      2.0  1908.0   2013.0       Good      3       3
# 20  20009.0      3.0  1880.0   2009.0  Very Good      5       3
# 21  20009.0      3.0  1880.0   2009.0       Good      3       3
# 22  20009.0      2.0  1880.0   2010.0       Good      3       1
# 23  20009.0      2.0  1880.0   2010.0  Very Good      3       2
# 24  20009.0      2.0  1880.0   2004.0       Good      3       2
# 25  20009.0      2.0  1880.0   2010.0       Good      4       1
# 26  20009.0      3.0  1900.0   2004.0    Average      5       1
# 27  20009.0      3.0  1900.0   1963.0    Average      3       3
# 28  20009.0      4.0  1900.0   1960.0    Average      4       3
# 29  20009.0      3.0  1900.0   2014.0  Very Good      3       3
# ..      ...      ...     ...      ...        ...    ...     ...
# 70  20009.0      3.0  1885.0   2008.0       Good      4       3
# 71  20009.0      2.0  1907.0   2005.0       Good      3       2
# 72  20009.0      2.0  1907.0   2014.0  Very Good      3       4
# 73  20009.0      2.0  1907.0   2011.0       Good      2       2
# 74  20009.0      2.0  1979.0      NaN    Average      4       2
# 75  20009.0      2.0  1979.0      NaN    Average      3       2
# 76  20009.0      2.0  1979.0      NaN       Good      4       2
# 77  20009.0      2.0  1979.0      NaN    Average      3       2
# 78  20009.0      2.0  1979.0   2012.0  Very Good      4       2
# 79  20009.0      2.0  1979.0   2010.0    Average      3       2
# 80  20009.0      2.0  1979.0      NaN    Average      3       2
# 81  20009.0      2.0  1979.0   2014.0       Good      3       2
# 82  20009.0      2.0  1979.0   2007.0  Very Good      4       3
# 83  20009.0      2.0  1979.0      NaN    Average      3       2
# 84  20009.0      2.0  1900.0   2001.0       Good      3       2
# 85  20009.0      2.0  1865.0   2012.0       Good      3       3
# 86  20009.0      3.0  1870.0   2011.0       Good      4       3
# 87  20009.0      2.0  1865.0      NaN    Average      3       1
# 88  20009.0      2.0  1865.0      NaN    Average      4       2
# 89  20009.0      2.0  1865.0   1990.0       Good      2       2
# 90  20009.0      3.0  1940.0      NaN    Average      4       6
# 91  20009.0      3.0  1905.0   2008.0       Good      4       4
# 92  20037.0      2.0  1909.0      NaN       Good      4       2
# 93  20037.0      2.0  1898.0   2000.0       Good      6       2
# 94  20009.0      4.0  1890.0      NaN    Average      7       4
# 95  20009.0      3.0  1948.0      NaN    Average      5       3
# 96  20009.0      2.0  1906.0   2004.0       Good      3       2
# 97  20009.0      4.0  1900.0   2013.0    Average      4       4
# 98  20009.0      3.0  1951.0      NaN       Good      4       2
# 99  20009.0      3.0  1890.0      NaN    Average      6       4
#
#              HEAT AC      PRICE
# 0       Warm Cool  Y  1095000.0
# 1       Warm Cool  Y        NaN
# 2   Hot Water Rad  Y  2100000.0
# 3   Hot Water Rad  Y  1602000.0
# 4       Warm Cool  Y        NaN
# 5   Hot Water Rad  Y  1950000.0
# 6       Warm Cool  Y        NaN
# 7   Hot Water Rad  Y  1050000.0
# 8       Warm Cool  Y  1430000.0
# 9   Hot Water Rad  Y        NaN
# 10     Forced Air  N        NaN
# 11  Hot Water Rad  Y        NaN
# 12  Hot Water Rad  N        NaN
# 13      Warm Cool  Y        NaN
# 14      Warm Cool  Y  1325000.0
# 15      Warm Cool  Y        NaN
# 16      Warm Cool  Y  1240000.0
# 17  Hot Water Rad  N        NaN
# 18  Hot Water Rad  Y        NaN
# 19  Hot Water Rad  Y   592250.0
# 20  Hot Water Rad  Y    33232.0
# 21     Forced Air  Y        NaN
# 22     Forced Air  Y   907400.0
# 23     Forced Air  Y  1065000.0
# 24  Hot Water Rad  Y  1100000.0
# 25  Hot Water Rad  N    20000.0
# 26  Hot Water Rad  N        NaN
# 27  Hot Water Rad  Y   703700.0
# 28      Warm Cool  Y        NaN
# 29     Forced Air  Y  1210000.0
# ..            ... ..        ...
# 70     Forced Air  Y   990000.0
# 71      Warm Cool  Y   682500.0
# 72      Warm Cool  Y   993500.0
# 73      Warm Cool  Y   745000.0
# 74      Warm Cool  Y        NaN
# 75      Warm Cool  Y        NaN
# 76      Warm Cool  Y   848500.0
# 77      Warm Cool  Y   277000.0
# 78      Warm Cool  Y  1155000.0
# 79      Warm Cool  Y        NaN
# 80      Warm Cool  Y        NaN
# 81      Warm Cool  Y  1363000.0
# 82      Warm Cool  Y  1148000.0
# 83      Warm Cool  Y        NaN
# 84      Warm Cool  Y        NaN
# 85  Hot Water Rad  Y   900000.0
# 86      Warm Cool  Y  1440000.0
# 87  Hot Water Rad  Y        NaN
# 88  Hot Water Rad  N        NaN
# 89      Warm Cool  Y   872000.0
# 90  Hot Water Rad  N  1500000.0
# 91      Warm Cool  Y  1925000.0
# 92  Hot Water Rad  N   360000.0
# 93  Hot Water Rad  N        NaN
# 94  Hot Water Rad  N        NaN
# 95  Hot Water Rad  N        NaN
# 96      Warm Cool  Y  1280000.0
# 97      Warm Cool  Y   770000.0
# 98  Hot Water Rad  Y  1560000.0
# 99  Hot Water Rad  N  1351830.0
#
# [100 rows x 10 columns]

# %%
#Checking that each column has the right type
df_new.dtypes
# Out:
# ZIPCODE    float64
# STORIES    float64
# AYB        float64
# YR_RMDL    float64
# CNDTN       object
# BEDRM        int64
# BATHRM       int64
# HEAT        object
# AC          object
# PRICE      float64
# dtype: object

# %%
#find out missing values per columns
df_new.isnull().sum()
# Out:
# ZIPCODE        1
# STORIES    52305
# AYB          271
# YR_RMDL    78029
# CNDTN      52261
# BEDRM          0
# BATHRM         0
# HEAT           0
# AC             0
# PRICE      60741
# dtype: int64

# %% [markdown]
# # Cleaning out the Data

# %%
#Looking for missing zipcode, using original Data Frame since it contains the address
missing_zip=df_new.loc[df_new['ZIPCODE'].isnull()]
missing_zip.head()
# Out:
#         ZIPCODE  STORIES     AYB  YR_RMDL    CNDTN  BEDRM  BATHRM  \
# 104610      NaN      2.0  1938.0      NaN  Average      4       2
#
#                  HEAT AC  PRICE
# 104610  Hot Water Rad  N    NaN

# %%
#Getting the index numbers of rows with missing zipcode
mals= list(missing_zip.index)
mals
# Out:
# [104610]

# %%
#CAN IT BE REPLACED

# %%
#looking for rows with missing data under in the price row
missing_price=df_new.loc[df_new['PRICE'].isnull()]
missing_price.head()
# Out:
#     ZIPCODE  STORIES     AYB  YR_RMDL    CNDTN  BEDRM  BATHRM           HEAT  \
# 1   20009.0      3.0  1898.0   2007.0     Good      5       3      Warm Cool
# 4   20009.0      3.0  1913.0   2012.0     Good      3       2      Warm Cool
# 6   20009.0      2.0  1917.0   1988.0  Average      2       1      Warm Cool
# 9   20009.0      2.0  1908.0   1979.0  Average      2       1  Hot Water Rad
# 10  20009.0      3.0  1890.0   1950.0     Fair      5       3     Forced Air
#
#    AC  PRICE
# 1   Y    NaN
# 4   Y    NaN
# 6   Y    NaN
# 9   Y    NaN
# 10  N    NaN

# %%
#Getting the index numbers of rows with missing prices
mals= list(missing_price.index)

# %%
#Define bins as 1700-1799, 1800-1899, 1900-1949, 1949-1999, 2000-2009, 2010-2017, add a heatmap? 
bins = [1700, 1800, 1900, 1950, 2000, 2010, 2018]

# Create names for the four groups
year_brackets = ['300', '200', '100', '50', '20', '10']

#make new column with letter grades
df_new['ageOfHouse'] = pd.cut(df_new['AYB'], bins, labels=year_brackets)
df_new.head()
# Out:
# C:\Users\carbo\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    ZIPCODE  STORIES     AYB  YR_RMDL      CNDTN  BEDRM  BATHRM           HEAT  \
# 0  20009.0      3.0  1910.0   1988.0       Good      4       4      Warm Cool
# 1  20009.0      3.0  1898.0   2007.0       Good      5       3      Warm Cool
# 2  20009.0      3.0  1910.0   2009.0  Very Good      5       3  Hot Water Rad
# 3  20009.0      3.0  1900.0   2003.0       Good      5       3  Hot Water Rad
# 4  20009.0      3.0  1913.0   2012.0       Good      3       2      Warm Cool
#
#   AC      PRICE ageOfHouse
# 0  Y  1095000.0        100
# 1  Y        NaN        200
# 2  Y  2100000.0        100
# 3  Y  1602000.0        200
# 4  Y        NaN        100

# %%
#looking for the average price of each houses by zipcodes, condition, ageOfHouse, bedroom and bathroom
df_new.groupby(['CNDTN','ageOfHouse','ZIPCODE','BATHRM','BEDRM',])['PRICE'].mean()
# Out:
# CNDTN      ageOfHouse  ZIPCODE  BATHRM  BEDRM
# Average    300         20001.0  1       2        2.850000e+05
#                        20002.0  1       3                 NaN
#                        20003.0  1       3                 NaN
#                                 2       3                 NaN
#                        20005.0  3       3                 NaN
#                        20007.0  1       1        8.250000e+05
#                                 2       2                 NaN
#                                 3       3        1.550000e+06
#                                         4                 NaN
#                                 5       4                 NaN
#                                         6        5.250000e+06
#                        20008.0  2       3                 NaN
#                        20009.0  2       3        1.100000e+06
#                                 3       4        8.460000e+05
#                        20011.0  1       3        6.500000e+05
#            200         20001.0  0       0        9.010000e+05
#                                 1       0        4.163750e+05
#                                         1        3.092000e+05
#                                         2        3.525305e+05
#                                         3        4.602403e+05
#                                         4        5.579944e+05
#                                         5                 NaN
#                                         6        2.750000e+05
#                                 2       0        1.410900e+05
#                                         2        3.881348e+05
#                                         3        5.464418e+05
#                                         4        3.917221e+05
#                                         5        5.246390e+05
#                                         6        4.440000e+05
#                                         7        8.300000e+04
#                                                      ...
# Very Good  10          20018.0  3       3        4.374249e+05
#                                         4        5.315799e+05
#                                 4       4        3.350000e+05
#                                         5        4.833964e+05
#                                 5       6        1.050000e+06
#                        20019.0  2       3        3.623003e+05
#                                         4        3.027561e+05
#                                 3       3        3.892273e+05
#                                         4        3.147974e+05
#                                         5        3.132500e+05
#                                 4       4        2.700000e+05
#                                         5        3.424167e+05
#                                         6        3.898333e+05
#                                 6       6        4.000000e+04
#                        20020.0  2       3        3.393128e+05
#                                         4        3.477129e+05
#                                 3       3        3.403588e+05
#                                         4        3.839225e+05
#                                         5        9.250000e+05
#                                 4       4        5.369000e+05
#                                 6       7        3.775000e+05
#                                 7       8        6.500000e+05
#                        20032.0  2       3        4.705792e+05
#                                         4        5.280577e+05
#                                 3       3        3.825365e+05
#                                         4        4.821392e+05
#                                         5        6.449900e+05
#                                 4       3        3.566011e+05
#                                         4        4.600900e+05
#                                         6                 NaN
# Name: PRICE, Length: 4380, dtype: float64

# %%
#fill out missing price rows
df_new['PRICE'].fillna(df_new.groupby(['CNDTN','ageOfHouse','ZIPCODE','BATHRM','BEDRM',])['PRICE'].transform('mean'), inplace=True)

# %%
#find out missing values per columns
df_new.isnull().sum()
# Out:
# ZIPCODE           1
# STORIES       52305
# AYB             271
# YR_RMDL       78029
# CNDTN         52261
# BEDRM             0
# BATHRM            0
# HEAT              0
# AC                0
# PRICE         13349
# ageOfHouse      272
# dtype: int64

# %%
#for remaining PRICE missing, replace it with average, first find average of column
df_new["PRICE"].fillna(df_new["PRICE"].mean(), inplace=True)

# %%
#find out missing values per columns
df_new.isnull().sum()
# Out:
# ZIPCODE           1
# STORIES       52305
# AYB             271
# YR_RMDL       78029
# CNDTN         52261
# BEDRM             0
# BATHRM            0
# HEAT              0
# AC                0
# PRICE             0
# ageOfHouse      272
# dtype: int64

# %%
#Getting rid of the missing AYB values
df_new['AYB'].fillna(df_new.groupby(['PRICE', 'ZIPCODE'])['AYB'].transform('mean'), inplace=True)

# %%
#for remaining AYB missing, replace it with average
df_new["AYB"].fillna(df_new["AYB"].mean(), inplace=True)

# %%
#find out missing values per columns
df_new.isnull().sum()
# Out:
# ZIPCODE           1
# STORIES       52305
# AYB               0
# YR_RMDL       78029
# CNDTN         52261
# BEDRM             0
# BATHRM            0
# HEAT              0
# AC                0
# PRICE             0
# ageOfHouse      272
# dtype: int64

# %%
#groupby zipcodes, add a violin graph 
df_new['ZIPCODE'].value_counts()
# Out:
# 20011.0    16352
# 20002.0    16310
# 20009.0    13171
# 20019.0    12458
# 20016.0    10644
# 20001.0    10549
# 20020.0     9805
# 20007.0     9029
# 20003.0     8015
# 20008.0     6801
# 20010.0     6428
# 20018.0     5670
# 20017.0     5622
# 20015.0     5337
# 20032.0     5111
# 20012.0     4118
# 20037.0     3730
# 20005.0     3404
# 20024.0     3105
# 20036.0     1892
# 20004.0     1082
# 20392.0      186
# 20006.0      118
# 20052.0       19
# Name: ZIPCODE, dtype: int64

# %%
#average price per Zipcode
df_new['PRICE'].groupby(df_new['ZIPCODE']).mean()
# Out:
# ZIPCODE
# 20001.0    5.228489e+05
# 20002.0    4.451390e+05
# 20003.0    5.846604e+05
# 20004.0    5.272483e+05
# 20005.0    2.407118e+06
# 20006.0    4.362055e+05
# 20007.0    9.536383e+05
# 20008.0    8.967724e+05
# 20009.0    6.558534e+05
# 20010.0    5.049202e+05
# 20011.0    3.915050e+05
# 20012.0    4.564372e+05
# 20015.0    7.590530e+05
# 20016.0    3.934175e+06
# 20017.0    3.812083e+05
# 20018.0    3.665161e+05
# 20019.0    2.196687e+05
# 20020.0    2.615370e+05
# 20024.0    4.681315e+05
# 20032.0    2.908802e+05
# 20036.0    5.347953e+05
# 20037.0    6.618564e+05
# 20052.0    7.120840e+05
# 20392.0    4.816521e+05
# Name: PRICE, dtype: float64

# %% [markdown]
# # Looking only at ZipCode 20003

# %%
#Since the data is too big for a swarmplot, I'll do one of zipcode 20003 and Conditions, first we'll get the information 
#for 20003
df_20003 = df_new.loc[df['ZIPCODE'] == 20003] 
df_20003
# Out:
#         ZIPCODE  STORIES     AYB  YR_RMDL      CNDTN  BEDRM  BATHRM  \
# 3308    20003.0      2.0  1900.0      NaN    Average      2       1
# 3603    20003.0      2.0  1890.0   1992.0    Average      3       1
# 3604    20003.0      2.0  1890.0   2007.0    Average      2       1
# 3605    20003.0      2.0  1890.0   2012.0    Average      3       1
# 3606    20003.0      2.0  1890.0   2010.0       Good      3       2
# 3607    20003.0      2.0  1905.0   1993.0    Average      3       1
# 3608    20003.0      3.0  2009.0      NaN  Excellent      4       4
# 3609    20003.0      3.0  2009.0      NaN  Very Good      3       3
# 3610    20003.0      3.0  2009.0      NaN  Excellent      3       3
# 3611    20003.0      3.0  2009.0      NaN  Excellent      4       3
# 3612    20003.0      3.0  2009.0      NaN  Excellent      3       3
# 3613    20003.0      3.0  2009.0      NaN  Very Good      4       3
# 3614    20003.0      3.0  2009.0      NaN  Excellent      4       4
# 3615    20003.0      3.0  2009.0      NaN       Good      3       2
# 3616    20003.0      3.0  2009.0      NaN  Very Good      3       2
# 3617    20003.0      3.0  2009.0      NaN  Excellent      4       3
# 3618    20003.0      3.0  2009.0      NaN       Good      9       6
# 3619    20003.0      3.0  2009.0      NaN  Excellent      3       2
# 3620    20003.0      3.0  2009.0      NaN       Good      3       2
# 3621    20003.0      3.0  2009.0      NaN       Good      3       2
# 3622    20003.0      3.0  2010.0      NaN  Very Good      2       3
# 3623    20003.0      3.0  2010.0      NaN  Very Good      3       2
# 3624    20003.0      3.0  2010.0      NaN  Very Good      3       2
# 3625    20003.0      3.0  2010.0      NaN  Excellent      3       2
# 3626    20003.0      3.0  2010.0      NaN       Good      3       2
# 3639    20003.0      2.0  1909.0   1976.0    Average      3       1
# 3640    20003.0      2.0  1890.0   2015.0    Average      4       2
# 3641    20003.0      2.0  1900.0   1966.0       Good      4       2
# 3642    20003.0      2.0  1908.0   2015.0       Good      2       1
# 3643    20003.0      2.0  1918.0   2006.0  Very Good      4       3
# ...         ...      ...     ...      ...        ...    ...     ...
# 158175  20003.0      NaN  2009.0      NaN        NaN      2       2
# 158176  20003.0      NaN  2009.0      NaN        NaN      1       1
# 158177  20003.0      NaN  2009.0      NaN        NaN      2       2
# 158178  20003.0      NaN  2009.0      NaN        NaN      2       2
# 158179  20003.0      NaN  2009.0      NaN        NaN      1       1
# 158180  20003.0      NaN  2009.0      NaN        NaN      1       1
# 158181  20003.0      NaN  2009.0      NaN        NaN      1       1
# 158182  20003.0      NaN  2009.0      NaN        NaN      1       1
# 158183  20003.0      NaN  2009.0      NaN        NaN      2       2
# 158184  20003.0      NaN  2009.0      NaN        NaN      2       2
# 158185  20003.0      NaN  2009.0      NaN        NaN      0       1
# 158186  20003.0      NaN  2009.0      NaN        NaN      0       1
# 158187  20003.0      NaN  2009.0      NaN        NaN      1       2
# 158188  20003.0      NaN  2009.0      NaN        NaN      1       2
# 158189  20003.0      NaN  2009.0      NaN        NaN      1       2
# 158190  20003.0      NaN  2009.0      NaN        NaN      1       2
# 158191  20003.0      NaN  2009.0      NaN        NaN      2       2
# 158192  20003.0      NaN  2009.0      NaN        NaN      1       1
# 158193  20003.0      NaN  2009.0      NaN        NaN      2       2
# 158194  20003.0      NaN  2009.0      NaN        NaN      2       2
# 158195  20003.0      NaN  2009.0      NaN        NaN      1       1
# 158196  20003.0      NaN  2009.0      NaN        NaN      1       1
# 158197  20003.0      NaN  2009.0      NaN        NaN      1       1
# 158198  20003.0      NaN  2009.0      NaN        NaN      1       1
# 158199  20003.0      NaN  2009.0      NaN        NaN      2       2
# 158200  20003.0      NaN  2009.0      NaN        NaN      2       2
# 158201  20003.0      NaN  2009.0      NaN        NaN      0       1
# 158202  20003.0      NaN  2009.0      NaN        NaN      0       1
# 158203  20003.0      NaN  2009.0      NaN        NaN      1       2
# 158204  20003.0      NaN  2009.0      NaN        NaN      1       2
#
#                  HEAT AC         PRICE ageOfHouse
# 3308    Hot Water Rad  N  3.354119e+05        200
# 3603    Hot Water Rad  N  3.454947e+05        200
# 3604       Forced Air  Y  3.090000e+05        200
# 3605    Hot Water Rad  Y  3.510000e+05        200
# 3606    Hot Water Rad  Y  3.999990e+05        200
# 3607        Warm Cool  Y  3.479418e+05        100
# 3608       Forced Air  Y  8.273100e+05         20
# 3609       Forced Air  Y  7.612078e+05         20
# 3610       Forced Air  Y  7.247850e+05         20
# 3611       Forced Air  Y  7.377500e+05         20
# 3612       Forced Air  Y  7.814250e+05         20
# 3613       Forced Air  Y  6.882560e+05         20
# 3614       Forced Air  Y  8.840050e+05         20
# 3615       Forced Air  Y  3.583550e+05         20
# 3616       Forced Air  Y  8.019322e+05         20
# 3617       Forced Air  Y  7.428200e+05         20
# 3618       Forced Air  Y  7.745851e+05         20
# 3619       Forced Air  Y  5.420292e+05         20
# 3620       Forced Air  Y  3.758450e+05         20
# 3621       Forced Air  Y  4.303600e+05         20
# 3622       Forced Air  Y  7.370200e+05         20
# 3623       Forced Air  Y  5.841550e+05         20
# 3624       Forced Air  Y  9.750000e+05         20
# 3625       Forced Air  Y  9.850000e+05         20
# 3626       Forced Air  Y  3.060000e+05         20
# 3639        Warm Cool  Y  3.479418e+05        100
# 3640    Hot Water Rad  Y  1.030000e+06        200
# 3641       Forced Air  Y  1.006000e+06        200
# 3642    Hot Water Rad  Y  4.720000e+05        100
# 3643       Forced Air  Y  1.174777e+06        100
# ...               ... ..           ...        ...
# 158175        Ht Pump  Y  7.559000e+05         20
# 158176        Ht Pump  Y  4.399000e+05         20
# 158177        Ht Pump  Y  6.850000e+05         20
# 158178        Ht Pump  Y  6.959000e+05         20
# 158179        Ht Pump  Y  3.850000e+05         20
# 158180        Ht Pump  Y  5.000000e+05         20
# 158181        Ht Pump  Y  4.100000e+05         20
# 158182        Ht Pump  Y  3.950000e+05         20
# 158183        Ht Pump  Y  6.390000e+05         20
# 158184        Ht Pump  Y  8.450000e+05         20
# 158185        Ht Pump  Y  7.745851e+05         20
# 158186        Ht Pump  Y  3.099000e+05         20
# 158187        Ht Pump  Y  5.990000e+05         20
# 158188        Ht Pump  Y  6.000000e+05         20
# 158189        Ht Pump  Y  5.950000e+05         20
# 158190        Ht Pump  Y  5.230000e+05         20
# 158191        Ht Pump  Y  8.375000e+05         20
# 158192        Ht Pump  Y  4.900000e+05         20
# 158193        Ht Pump  Y  5.349000e+05         20
# 158194        Ht Pump  Y  5.500000e+05         20
# 158195        Ht Pump  Y  5.180000e+05         20
# 158196        Ht Pump  Y  4.149000e+05         20
# 158197        Ht Pump  Y  4.270000e+05         20
# 158198        Ht Pump  Y  4.390000e+05         20
# 158199        Ht Pump  Y  5.830000e+05         20
# 158200        Ht Pump  Y  6.550000e+05         20
# 158201        Ht Pump  Y  3.775000e+05         20
# 158202        Ht Pump  Y  2.929000e+05         20
# 158203        Ht Pump  Y  6.315000e+05         20
# 158204        Ht Pump  Y  6.000000e+05         20
#
# [8015 rows x 11 columns]

# %%
#create a dataframe containing the stats for each Zipcode
#drop 'ZIPCODE', 'HEAT', 'AC','STORIES', 'BEDRM', 'BATHRM', 'YR_RMD
stats_df_20003 = df_new.drop(['ZIPCODE', 'HEAT', 'AC','STORIES', 'BEDRM', 'BATHRM', 'CNDTN','YR_RMDL'], axis=1)
stats_df_20003.head()
# Out:
#       AYB         PRICE ageOfHouse
# 0  1910.0  1.095000e+06        100
# 1  1898.0  1.161916e+06        200
# 2  1910.0  2.100000e+06        100
# 3  1900.0  1.602000e+06        200
# 4  1913.0  7.737047e+05        100

# %%
#average price in 20004
df_20003['PRICE'].mean()
# Out:
# 584660.4079599275

# %%
#box plot for Zipcode 20003

plt.subplots(figsize=(6,40))



#add a boxplot zipcode vs prices
sns.boxplot(x='ageOfHouse',y='PRICE',data=df_20003)

# %%
#Most expensive houses per Zipcode 20004
df_20003['PRICE'].max()
# Out:
# 3300000.0

# %%
#least expensive house in 20004
df_20003['PRICE'].min()
# Out:
# 15000.0

# %%
#Finding and getting rid of outliers
q1 = df_20003['PRICE'].quantile(.25)
q3 = df_20003['PRICE'].quantile(.75)
iqr = q3-q1
toprange = q3 + iqr * 1.5
botrange = q1 - iqr * 1.5

copydf_20003 = df_20003.copy()
copydf_20003 = df_20003.drop(copydf_20003[copydf_20003['PRICE'] > toprange].index)
copydf_20003 = copydf_20003.drop(copydf_20003[copydf_20003['PRICE'] < botrange].index)

copydf_20003.head()
# Out:
#       ZIPCODE  STORIES     AYB  YR_RMDL    CNDTN  BEDRM  BATHRM  \
# 3308  20003.0      2.0  1900.0      NaN  Average      2       1
# 3603  20003.0      2.0  1890.0   1992.0  Average      3       1
# 3604  20003.0      2.0  1890.0   2007.0  Average      2       1
# 3605  20003.0      2.0  1890.0   2012.0  Average      3       1
# 3606  20003.0      2.0  1890.0   2010.0     Good      3       2
#
#                HEAT AC          PRICE ageOfHouse
# 3308  Hot Water Rad  N  335411.902778        200
# 3603  Hot Water Rad  N  345494.677966        200
# 3604     Forced Air  Y  309000.000000        200
# 3605  Hot Water Rad  Y  351000.000000        200
# 3606  Hot Water Rad  Y  399999.000000        200

# %%
plt.subplots(figsize=(40, 40))
sns.boxplot(x='ageOfHouse',y='PRICE',data=copydf_20003)

# %%
#Find oldest house in 20003
df_20003['AYB'].min()
# Out:
# 1776.0

# %%
#Find latest house in 20003
df_20003['AYB'].max()
# Out:
# 2018.0

# %%
#boxplot highligthing Condition vs Price
plt.subplots(figsize=(40, 40))
sns.boxplot(x='CNDTN',y='PRICE',data=copydf_20003)
